# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Jun  4 19:43:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    32W / 250W |   2595MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %% [markdown]
# Load data

# %%
#### Load dataset ####
dataPath ='/content/drive/Shared drives/ECE228/final/dataset/ae/'
inputSet  = np.load(dataPath + 'inputSet1.npy')
labelSet = np.load(dataPath + 'labelSet1.npy')

#### Check US image ####
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.imshow(inputSet[0,:,:], 'gray')
plt.title('data with noise')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(1,2,2)
plt.imshow(labelSet[0,:,:], 'gray')
plt.title('ground truth')
plt.xlabel('channel')
plt.ylabel('depth')
plt.show()

# %% [markdown]
# Build Unet

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'random_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'random_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x
  
def get_unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

#input_img = Input((imgSizeY, imgSizeX, 1), name='img')
input_img = Input((176, 64, 1), name='img')
unet = get_unet(input_img)
unet.compile(loss='mse', optimizer='adam')
print(unet.summary())
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 176, 64, 1)   0
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 176, 64, 16)  160         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 176, 64, 16)  64          conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 176, 64, 16)  0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D) (None, 88, 32, 16)   0           activation_200[0][0]
# __________________________________________________________________________________________________
# dropout_89 (Dropout)            (None, 88, 32, 16)   0           max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 88, 32, 32)   4640        dropout_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 88, 32, 32)   128         conv2d_213[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 88, 32, 32)   0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, 44, 16, 32)   0           activation_202[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 44, 16, 32)   0           max_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 44, 16, 64)   18496       dropout_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 44, 16, 64)   256         conv2d_215[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 44, 16, 64)   0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 22, 8, 64)    0           activation_204[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 22, 8, 64)    0           max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 22, 8, 128)   73856       dropout_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 22, 8, 128)   512         conv2d_217[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 22, 8, 128)   0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 11, 4, 128)   0           activation_206[0][0]
# __________________________________________________________________________________________________
# dropout_92 (Dropout)            (None, 11, 4, 128)   0           max_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 11, 4, 256)   295168      dropout_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 11, 4, 256)   1024        conv2d_219[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 11, 4, 256)   0           batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_45 (Conv2DTran (None, 22, 8, 128)   295040      activation_208[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 22, 8, 256)   0           conv2d_transpose_45[0][0]
#                                                                  activation_206[0][0]
# __________________________________________________________________________________________________
# dropout_93 (Dropout)            (None, 22, 8, 256)   0           concatenate_45[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 22, 8, 128)   295040      dropout_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 22, 8, 128)   512         conv2d_221[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 22, 8, 128)   0           batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_46 (Conv2DTran (None, 44, 16, 64)   73792       activation_210[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 44, 16, 128)  0           conv2d_transpose_46[0][0]
#                                                                  activation_204[0][0]
# __________________________________________________________________________________________________
# dropout_94 (Dropout)            (None, 44, 16, 128)  0           concatenate_46[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 44, 16, 64)   73792       dropout_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 44, 16, 64)   256         conv2d_223[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 44, 16, 64)   0           batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_47 (Conv2DTran (None, 88, 32, 32)   18464       activation_212[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 88, 32, 64)   0           conv2d_transpose_47[0][0]
#                                                                  activation_202[0][0]
# __________________________________________________________________________________________________
# dropout_95 (Dropout)            (None, 88, 32, 64)   0           concatenate_47[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 88, 32, 32)   18464       dropout_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 88, 32, 32)   128         conv2d_225[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 88, 32, 32)   0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_48 (Conv2DTran (None, 176, 64, 16)  4624        activation_214[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 176, 64, 32)  0           conv2d_transpose_48[0][0]
#                                                                  activation_200[0][0]
# __________________________________________________________________________________________________
# dropout_96 (Dropout)            (None, 176, 64, 32)  0           concatenate_48[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 176, 64, 16)  4624        dropout_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 176, 64, 16)  64          conv2d_227[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 176, 64, 16)  0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 176, 64, 1)   17          activation_216[0][0]
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# None

# %% [markdown]
# wash data

# %%
#### Load dataset #### (data the has already been normalized)
x_train  = np.load('x_train.npy')
y_train = np.load('y_train.npy')
x_test  = np.load('x_test.npy')
y_test = np.load('y_test.npy')
print(x_train.shape)
print(y_test.shape)

#### Check US image ####
plt.figure(figsize=(15,7))
plt.subplot(1,4,1)
plt.imshow(x_train[0,:,:,0], 'gray')
plt.title('train data with noise')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(1,4,2)
plt.imshow(y_train[0,:,:,0], 'gray')
plt.title('train ground truth')
plt.xlabel('channel')
plt.ylabel('depth')
plt.figure(figsize=(15,7))
plt.subplot(1,4,3)
plt.imshow(x_test[0,:,:,0], 'gray')
plt.title('test data with noise')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(1,4,4)
plt.imshow(y_test[0,:,:,0], 'gray')
plt.title('test ground truth')
plt.xlabel('channel')
plt.ylabel('depth')
plt.show()
# Out:
# (1000, 176, 64, 1)
# (100, 176, 64, 1)

# %% [markdown]
# Train the model

# %%
# callback for dynamic learning rate
callbacks = [
    EarlyStopping(patience=60, verbose=1),
    ReduceLROnPlateau(factor=0.0001, patience=50, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-unet.h5', verbose=1, save_best_only=True, save_weights_only=True)
]
#history_conv_unet = unet.fit(x_train, y_train, callbacks=callbacks, validation_split=0.1, epochs=500, batch_size=15, shuffle=True)
history_conv_unet = unet.fit(x_train, y_train, callbacks=callbacks, validation_data=(x_test, y_test), epochs=800, batch_size=15, shuffle=True)
#history_conv_unet = unet.fit(x_train, y_train, validation_split=0.2, epochs=300, batch_size=25, shuffle=True)

# Plot loss versus epoch.
plt.figure(figsize=(15,7))
plt.plot(history_conv_unet.history['loss'],label='loss')
plt.plot(history_conv_unet.history['val_loss'],label='val_loss')
plt.legend(loc='upper right')
plt.title('loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/800
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0691 - val_loss: 0.1762
#
# Epoch 00001: val_loss improved from inf to 0.17616, saving model to model-unet.h5
# Epoch 2/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0202 - val_loss: 0.0245
#
# Epoch 00002: val_loss improved from 0.17616 to 0.02455, saving model to model-unet.h5
# Epoch 3/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0125 - val_loss: 0.0183
#
# Epoch 00003: val_loss improved from 0.02455 to 0.01828, saving model to model-unet.h5
# Epoch 4/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0086 - val_loss: 0.0103
#
# Epoch 00004: val_loss improved from 0.01828 to 0.01027, saving model to model-unet.h5
# Epoch 5/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0070 - val_loss: 0.0086
#
# Epoch 00005: val_loss improved from 0.01027 to 0.00864, saving model to model-unet.h5
# Epoch 6/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0061 - val_loss: 0.0075
#
# Epoch 00006: val_loss improved from 0.00864 to 0.00751, saving model to model-unet.h5
# Epoch 7/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0053 - val_loss: 0.0070
#
# Epoch 00007: val_loss improved from 0.00751 to 0.00697, saving model to model-unet.h5
# Epoch 8/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0049 - val_loss: 0.0064
#
# Epoch 00008: val_loss improved from 0.00697 to 0.00642, saving model to model-unet.h5
# Epoch 9/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0072 - val_loss: 0.0618
#
# Epoch 00009: val_loss did not improve from 0.00642
# Epoch 10/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0065 - val_loss: 0.0063
#
# Epoch 00010: val_loss improved from 0.00642 to 0.00632, saving model to model-unet.h5
# Epoch 11/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0053 - val_loss: 0.0050
#
# Epoch 00011: val_loss improved from 0.00632 to 0.00504, saving model to model-unet.h5
# Epoch 12/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0047 - val_loss: 0.0040
#
# Epoch 00012: val_loss improved from 0.00504 to 0.00401, saving model to model-unet.h5
# Epoch 13/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0045 - val_loss: 0.0039
#
# Epoch 00013: val_loss improved from 0.00401 to 0.00387, saving model to model-unet.h5
# Epoch 14/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0042 - val_loss: 0.0037
#
# Epoch 00014: val_loss improved from 0.00387 to 0.00375, saving model to model-unet.h5
# Epoch 15/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00015: val_loss did not improve from 0.00375
# Epoch 16/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0040 - val_loss: 0.0038
#
# Epoch 00016: val_loss did not improve from 0.00375
# Epoch 17/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0038 - val_loss: 0.0036
#
# Epoch 00017: val_loss improved from 0.00375 to 0.00365, saving model to model-unet.h5
# Epoch 18/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0036 - val_loss: 0.0041
#
# Epoch 00018: val_loss did not improve from 0.00365
# Epoch 19/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0038
#
# Epoch 00019: val_loss did not improve from 0.00365
# Epoch 20/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0033
#
# Epoch 00020: val_loss improved from 0.00365 to 0.00335, saving model to model-unet.h5
# Epoch 21/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0036
#
# Epoch 00021: val_loss did not improve from 0.00335
# Epoch 22/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 0.0037
#
# Epoch 00022: val_loss did not improve from 0.00335
# Epoch 23/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 0.0035
#
# Epoch 00023: val_loss did not improve from 0.00335
# Epoch 24/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0031 - val_loss: 0.0035
#
# Epoch 00024: val_loss did not improve from 0.00335
# Epoch 25/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0031 - val_loss: 0.0035
#
# Epoch 00025: val_loss did not improve from 0.00335
# Epoch 26/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0030 - val_loss: 0.0032
#
# Epoch 00026: val_loss improved from 0.00335 to 0.00321, saving model to model-unet.h5
# Epoch 27/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0029 - val_loss: 0.0040
#
# Epoch 00027: val_loss did not improve from 0.00321
# Epoch 28/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0029 - val_loss: 0.0035
#
# Epoch 00028: val_loss did not improve from 0.00321
# Epoch 29/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0028 - val_loss: 0.0033
#
# Epoch 00029: val_loss did not improve from 0.00321
# Epoch 30/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0031 - val_loss: 0.0246
#
# Epoch 00030: val_loss did not improve from 0.00321
# Epoch 31/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0031 - val_loss: 0.0039
#
# Epoch 00031: val_loss did not improve from 0.00321
# Epoch 32/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0028 - val_loss: 0.0037
#
# Epoch 00032: val_loss did not improve from 0.00321
# Epoch 33/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00033: val_loss did not improve from 0.00321
# Epoch 34/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00034: val_loss did not improve from 0.00321
# Epoch 35/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00035: val_loss did not improve from 0.00321
# Epoch 36/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00036: val_loss did not improve from 0.00321
# Epoch 37/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0024 - val_loss: 0.0036
#
# Epoch 00037: val_loss did not improve from 0.00321
# Epoch 38/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00038: val_loss did not improve from 0.00321
# Epoch 39/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0024 - val_loss: 0.0035
#
# Epoch 00039: val_loss did not improve from 0.00321
# Epoch 40/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0024 - val_loss: 0.0040
#
# Epoch 00040: val_loss did not improve from 0.00321
# Epoch 41/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00041: val_loss did not improve from 0.00321
# Epoch 42/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00042: val_loss did not improve from 0.00321
# Epoch 43/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0022 - val_loss: 0.0037
#
# Epoch 00043: val_loss did not improve from 0.00321
# Epoch 44/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0022 - val_loss: 0.0038
#
# Epoch 00044: val_loss did not improve from 0.00321
# Epoch 45/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0021 - val_loss: 0.0035
#
# Epoch 00045: val_loss did not improve from 0.00321
# Epoch 46/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0021 - val_loss: 0.0040
#
# Epoch 00046: val_loss did not improve from 0.00321
# Epoch 47/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0021 - val_loss: 0.0035
#
# Epoch 00047: val_loss did not improve from 0.00321
# Epoch 48/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0020 - val_loss: 0.0036
#
# Epoch 00048: val_loss did not improve from 0.00321
# Epoch 49/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0020 - val_loss: 0.0035
#
# Epoch 00049: val_loss did not improve from 0.00321
# Epoch 50/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0020 - val_loss: 0.0033
#
# Epoch 00050: val_loss did not improve from 0.00321
# Epoch 51/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0019 - val_loss: 0.0035
#
# Epoch 00051: val_loss did not improve from 0.00321
# Epoch 52/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0019 - val_loss: 0.0036
#
# Epoch 00052: val_loss did not improve from 0.00321
# Epoch 53/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0019 - val_loss: 0.0037
#
# Epoch 00053: val_loss did not improve from 0.00321
# Epoch 54/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0018 - val_loss: 0.0037
#
# Epoch 00054: val_loss did not improve from 0.00321
# Epoch 55/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0018 - val_loss: 0.0035
#
# Epoch 00055: val_loss did not improve from 0.00321
# Epoch 56/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0018 - val_loss: 0.0033
#
# Epoch 00056: val_loss did not improve from 0.00321
# Epoch 57/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0031
#
# Epoch 00057: val_loss improved from 0.00321 to 0.00308, saving model to model-unet.h5
# Epoch 58/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0036
#
# Epoch 00058: val_loss did not improve from 0.00308
# Epoch 59/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0037
#
# Epoch 00059: val_loss did not improve from 0.00308
# Epoch 60/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0036
#
# Epoch 00060: val_loss did not improve from 0.00308
# Epoch 61/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0016 - val_loss: 0.0037
#
# Epoch 00061: val_loss did not improve from 0.00308
# Epoch 62/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0016 - val_loss: 0.0041
#
# Epoch 00062: val_loss did not improve from 0.00308
# Epoch 63/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0016 - val_loss: 0.0036
#
# Epoch 00063: val_loss did not improve from 0.00308
# Epoch 64/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0016 - val_loss: 0.0042
#
# Epoch 00064: val_loss did not improve from 0.00308
# Epoch 65/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0034
#
# Epoch 00065: val_loss did not improve from 0.00308
# Epoch 66/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0038
#
# Epoch 00066: val_loss did not improve from 0.00308
# Epoch 67/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0038
#
# Epoch 00067: val_loss did not improve from 0.00308
# Epoch 68/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0039
#
# Epoch 00068: val_loss did not improve from 0.00308
# Epoch 69/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0036
#
# Epoch 00069: val_loss did not improve from 0.00308
# Epoch 70/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0037
#
# Epoch 00070: val_loss did not improve from 0.00308
# Epoch 71/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0037
#
# Epoch 00071: val_loss did not improve from 0.00308
# Epoch 72/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0035
#
# Epoch 00072: val_loss did not improve from 0.00308
# Epoch 73/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0038
#
# Epoch 00073: val_loss did not improve from 0.00308
# Epoch 74/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0034
#
# Epoch 00074: val_loss did not improve from 0.00308
# Epoch 75/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0037
#
# Epoch 00075: val_loss did not improve from 0.00308
# Epoch 76/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0038
#
# Epoch 00076: val_loss did not improve from 0.00308
# Epoch 77/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0036
#
# Epoch 00077: val_loss did not improve from 0.00308
# Epoch 78/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0037
#
# Epoch 00078: val_loss did not improve from 0.00308
# Epoch 79/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0033
#
# Epoch 00079: val_loss did not improve from 0.00308
# Epoch 80/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0038
#
# Epoch 00080: val_loss did not improve from 0.00308
# Epoch 81/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0036
#
# Epoch 00081: val_loss did not improve from 0.00308
# Epoch 82/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0035
#
# Epoch 00082: val_loss did not improve from 0.00308
# Epoch 83/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0036
#
# Epoch 00083: val_loss did not improve from 0.00308
# Epoch 84/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0039
#
# Epoch 00084: val_loss did not improve from 0.00308
# Epoch 85/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0036
#
# Epoch 00085: val_loss did not improve from 0.00308
# Epoch 86/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0038
#
# Epoch 00086: val_loss did not improve from 0.00308
# Epoch 87/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0038
#
# Epoch 00087: val_loss did not improve from 0.00308
# Epoch 88/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0037
#
# Epoch 00088: val_loss did not improve from 0.00308
# Epoch 89/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0033
#
# Epoch 00089: val_loss did not improve from 0.00308
# Epoch 90/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0038
#
# Epoch 00090: val_loss did not improve from 0.00308
# Epoch 91/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00091: val_loss did not improve from 0.00308
# Epoch 92/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0036
#
# Epoch 00092: val_loss did not improve from 0.00308
# Epoch 93/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0032
#
# Epoch 00093: val_loss did not improve from 0.00308
# Epoch 94/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0039
#
# Epoch 00094: val_loss did not improve from 0.00308
# Epoch 95/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0033
#
# Epoch 00095: val_loss did not improve from 0.00308
# Epoch 96/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0037
#
# Epoch 00096: val_loss did not improve from 0.00308
# Epoch 97/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0036
#
# Epoch 00097: val_loss did not improve from 0.00308
# Epoch 98/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00098: val_loss did not improve from 0.00308
# Epoch 99/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0036
#
# Epoch 00099: val_loss did not improve from 0.00308
# Epoch 100/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0036
#
# Epoch 00100: val_loss did not improve from 0.00308
# Epoch 101/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0010 - val_loss: 0.0034
#
# Epoch 00101: val_loss did not improve from 0.00308
# Epoch 102/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0010 - val_loss: 0.0034
#
# Epoch 00102: val_loss did not improve from 0.00308
# Epoch 103/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0010 - val_loss: 0.0039
#
# Epoch 00103: val_loss did not improve from 0.00308
# Epoch 104/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0010 - val_loss: 0.0033
#
# Epoch 00104: val_loss did not improve from 0.00308
# Epoch 105/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0010 - val_loss: 0.0038
#
# Epoch 00105: val_loss did not improve from 0.00308
# Epoch 106/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0010 - val_loss: 0.0039
#
# Epoch 00106: val_loss did not improve from 0.00308
# Epoch 107/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0010 - val_loss: 0.0033
#
# Epoch 00107: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00107: val_loss did not improve from 0.00308
# Epoch 108/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.8447e-04 - val_loss: 0.0034
#
# Epoch 00108: val_loss did not improve from 0.00308
# Epoch 109/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.7413e-04 - val_loss: 0.0035
#
# Epoch 00109: val_loss did not improve from 0.00308
# Epoch 110/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.6705e-04 - val_loss: 0.0035
#
# Epoch 00110: val_loss did not improve from 0.00308
# Epoch 111/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.6530e-04 - val_loss: 0.0035
#
# Epoch 00111: val_loss did not improve from 0.00308
# Epoch 112/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.6261e-04 - val_loss: 0.0036
#
# Epoch 00112: val_loss did not improve from 0.00308
# Epoch 113/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.6201e-04 - val_loss: 0.0035
#
# Epoch 00113: val_loss did not improve from 0.00308
# Epoch 114/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.6091e-04 - val_loss: 0.0036
#
# Epoch 00114: val_loss did not improve from 0.00308
# Epoch 115/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.5941e-04 - val_loss: 0.0036
#
# Epoch 00115: val_loss did not improve from 0.00308
# Epoch 116/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.6107e-04 - val_loss: 0.0035
#
# Epoch 00116: val_loss did not improve from 0.00308
# Epoch 117/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 9.6002e-04 - val_loss: 0.0036
#
# Epoch 00117: val_loss did not improve from 0.00308
# Epoch 00117: early stopping

# %% [markdown]
# Test Model

# %%
decoded_data = unet.predict(x_test)
#Obtain encoder representation of data
from tensorflow.keras import backend as K
get_hl = K.function([unet.layers[0].input], [unet.layers[3].output])
unet_hl = get_hl([x_test])[0]

n = 2  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i,:,:,0])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display hidden layer representation
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(unet_hl[i,:,:,0])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n + n)
    plt.imshow(decoded_data[i,:,:,0])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# load the best model
unet.load_weights('model-unet.h5')

y_pred = unet.predict(x_test)

plt.figure(figsize=(15,12))
plt.subplot(2,5,1)
plt.imshow(x_test[0,:,:,0], 'gray')
plt.title('input test1(data with noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,2)
plt.imshow(y_pred[0,:,:,0], 'gray')
plt.title('prediction test1')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,3)
plt.imshow(y_test[0,:,:,0], 'gray')
plt.title('ground truth1(data wo noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,4)
plt.imshow(abs(y_test[0,:,:,0]-y_pred[0,:,:,0]), 'jet')
plt.title('prediction difference')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,5)
plt.imshow(abs(x_test[0,:,:,0]-y_test[0,:,:,0]), 'jet')
plt.title('input difference')
plt.xlabel('channel')
plt.ylabel('depth')


plt.subplot(2,5,6)
plt.imshow(x_test[1,:,:,0], 'gray')
plt.title('input test2(data with noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,7)
plt.imshow(y_pred[1,:,:,0], 'gray')
plt.title('prediction test2')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,8)
plt.imshow(y_test[1,:,:,0], 'gray')
plt.title('ground truth1(data wo noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,9)
plt.imshow(abs(y_test[1,:,:,0]-y_pred[1,:,:,0]), 'jet')
plt.title('prediction difference')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,10)
plt.imshow(abs(x_test[1,:,:,0]-y_test[1,:,:,0]), 'jet')
plt.title('input difference')
plt.xlabel('channel')
plt.ylabel('depth')
plt.show()

# %%
y_pred_t = unet.predict(x_train[:2,:,:,:])

plt.figure(figsize=(15,12))
plt.subplot(2,3,1)
plt.imshow(x_train[0,:,:,0], 'gray')
plt.title('input test1(data with noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,3,2)
plt.imshow(y_pred_t[0,:,:,0], 'gray')
plt.title('prediction test1')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,3,3)
plt.imshow(y_train[0,:,:,0], 'gray')
plt.title('ground truth1(data wo noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,3,4)
plt.imshow(x_train[1,:,:,0], 'gray')
plt.title('input test2(data with noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,3,5)
plt.imshow(y_pred_t[1,:,:,0], 'gray')
plt.title('prediction test2')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,3,6)
plt.imshow(y_train[1,:,:,0], 'gray')
plt.title('ground truth1(data wo noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.show()

# %%
#### Load dataset ####
dataPath ='/content/drive/Shared drives/ECE228/final/dataset/ae/'
inputSet  = np.load(dataPath + 'inputSet1.npy')
labelSet = np.load(dataPath + 'labelSet1.npy')

if not os.path.exists('./TEST_img'):
    os.mkdir('./TEST_img')


from keras.preprocessing.image import save_img
save_img('saveIMGtest.jpg', y_pred_t[0,:,:,:])
