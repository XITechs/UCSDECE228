# %% [markdown]
# Check GPU

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Jun  4 21:26:17 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Import lib

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Load data from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#### Load dataset #### (data the has already been normalized)
dataPath ='/content/drive/Shared drives/ECE228/final/dataset/ae/'

x_train  = np.load(dataPath + 'x_train.npy')
y_train = np.load(dataPath + 'y_train.npy')
x_test  = np.load(dataPath + 'x_test.npy')
y_test = np.load(dataPath + 'y_test.npy')
print(x_train.shape)
print(y_test.shape)

#### Check US image ####
plt.figure(figsize=(15,7))
plt.subplot(1,4,1)
plt.imshow(x_train[0,:,:,0], 'gray')
plt.title('train data with noise')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(1,4,2)
plt.imshow(y_train[0,:,:,0], 'gray')
plt.title('train ground truth')
plt.xlabel('channel')
plt.ylabel('depth')
plt.figure(figsize=(15,7))
plt.subplot(1,4,3)
plt.imshow(x_test[0,:,:,0], 'gray')
plt.title('test data with noise')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(1,4,4)
plt.imshow(y_test[0,:,:,0], 'gray')
plt.title('test ground truth')
plt.xlabel('channel')
plt.ylabel('depth')
plt.show()
# Out:
# (1000, 176, 64, 1)
# (100, 176, 64, 1)

# %% [markdown]
# Build Model

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'random_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'random_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x
  
def get_unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

input_img = Input((x_train.shape[1], x_train.shape[2], 1), name='img')
unet = get_unet(input_img)
unet.compile(loss='mse', optimizer='adam')
print(unet.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 176, 64, 1)   0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 176, 64, 16)  160         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 176, 64, 16)  64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 176, 64, 16)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 88, 32, 16)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 88, 32, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 88, 32, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 88, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 88, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 44, 16, 32)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 44, 16, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 44, 16, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 44, 16, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 44, 16, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 22, 8, 64)    0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 22, 8, 64)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 22, 8, 128)   73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 22, 8, 128)   512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 22, 8, 128)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 11, 4, 128)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 11, 4, 128)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 11, 4, 256)   295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 11, 4, 256)   1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 11, 4, 256)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 22, 8, 128)   295040      activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 22, 8, 256)   0           conv2d_transpose_1[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 22, 8, 256)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 22, 8, 128)   295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 22, 8, 128)   512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 22, 8, 128)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 44, 16, 64)   73792       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 44, 16, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 44, 16, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 44, 16, 64)   73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 44, 16, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 44, 16, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 88, 32, 32)   18464       activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 88, 32, 64)   0           conv2d_transpose_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 88, 32, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 88, 32, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 88, 32, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 88, 32, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 176, 64, 16)  4624        activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 176, 64, 32)  0           conv2d_transpose_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 176, 64, 32)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 176, 64, 16)  4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 176, 64, 16)  64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 176, 64, 16)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 176, 64, 1)   17          activation_18[0][0]
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Train the model

# %%
# callback for dynamic learning rate
callbacks = [
    EarlyStopping(patience=60, verbose=1),
    ReduceLROnPlateau(factor=0.001, patience=50, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-unet.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

history_conv_unet = unet.fit(x_train, y_train, callbacks=callbacks, validation_data=(x_test, y_test), epochs=800, batch_size=15, shuffle=True)

# Plot loss versus epoch.
plt.figure(figsize=(15,7))
plt.plot(history_conv_unet.history['loss'],label='loss')
plt.plot(history_conv_unet.history['val_loss'],label='val_loss')
plt.legend(loc='upper right')
plt.title('loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/800
# 1000/1000 [==============================] - 11s 11ms/step - loss: 0.0773 - val_loss: 0.0733
#
# Epoch 00001: val_loss improved from inf to 0.07328, saving model to model-unet.h5
# Epoch 2/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0244 - val_loss: 0.0317
#
# Epoch 00002: val_loss improved from 0.07328 to 0.03166, saving model to model-unet.h5
# Epoch 3/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0133 - val_loss: 0.0195
#
# Epoch 00003: val_loss improved from 0.03166 to 0.01949, saving model to model-unet.h5
# Epoch 4/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0092 - val_loss: 0.0138
#
# Epoch 00004: val_loss improved from 0.01949 to 0.01381, saving model to model-unet.h5
# Epoch 5/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0081 - val_loss: 0.0120
#
# Epoch 00005: val_loss improved from 0.01381 to 0.01197, saving model to model-unet.h5
# Epoch 6/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0079 - val_loss: 0.0092
#
# Epoch 00006: val_loss improved from 0.01197 to 0.00922, saving model to model-unet.h5
# Epoch 7/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0059 - val_loss: 0.0070
#
# Epoch 00007: val_loss improved from 0.00922 to 0.00698, saving model to model-unet.h5
# Epoch 8/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0052 - val_loss: 0.0056
#
# Epoch 00008: val_loss improved from 0.00698 to 0.00565, saving model to model-unet.h5
# Epoch 9/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0049 - val_loss: 0.0051
#
# Epoch 00009: val_loss improved from 0.00565 to 0.00507, saving model to model-unet.h5
# Epoch 10/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0045 - val_loss: 0.0043
#
# Epoch 00010: val_loss improved from 0.00507 to 0.00432, saving model to model-unet.h5
# Epoch 11/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0042 - val_loss: 0.0040
#
# Epoch 00011: val_loss improved from 0.00432 to 0.00403, saving model to model-unet.h5
# Epoch 12/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0040 - val_loss: 0.0038
#
# Epoch 00012: val_loss improved from 0.00403 to 0.00381, saving model to model-unet.h5
# Epoch 13/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00013: val_loss did not improve from 0.00381
# Epoch 14/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0037 - val_loss: 0.0038
#
# Epoch 00014: val_loss did not improve from 0.00381
# Epoch 15/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0039
#
# Epoch 00015: val_loss did not improve from 0.00381
# Epoch 16/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0036
#
# Epoch 00016: val_loss improved from 0.00381 to 0.00360, saving model to model-unet.h5
# Epoch 17/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0037
#
# Epoch 00017: val_loss did not improve from 0.00360
# Epoch 18/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 0.0044
#
# Epoch 00018: val_loss did not improve from 0.00360
# Epoch 19/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0031 - val_loss: 0.0044
#
# Epoch 00019: val_loss did not improve from 0.00360
# Epoch 20/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0030 - val_loss: 0.0040
#
# Epoch 00020: val_loss did not improve from 0.00360
# Epoch 21/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0037 - val_loss: 0.0043
#
# Epoch 00021: val_loss did not improve from 0.00360
# Epoch 22/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0036
#
# Epoch 00022: val_loss did not improve from 0.00360
# Epoch 23/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0030 - val_loss: 0.0034
#
# Epoch 00023: val_loss improved from 0.00360 to 0.00344, saving model to model-unet.h5
# Epoch 24/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0029 - val_loss: 0.0037
#
# Epoch 00024: val_loss did not improve from 0.00344
# Epoch 25/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00025: val_loss did not improve from 0.00344
# Epoch 26/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00026: val_loss improved from 0.00344 to 0.00330, saving model to model-unet.h5
# Epoch 27/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00027: val_loss did not improve from 0.00330
# Epoch 28/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0026 - val_loss: 0.0034
#
# Epoch 00028: val_loss did not improve from 0.00330
# Epoch 29/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00029: val_loss did not improve from 0.00330
# Epoch 30/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00030: val_loss improved from 0.00330 to 0.00310, saving model to model-unet.h5
# Epoch 31/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00031: val_loss did not improve from 0.00310
# Epoch 32/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00032: val_loss did not improve from 0.00310
# Epoch 33/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0024 - val_loss: 0.0033
#
# Epoch 00033: val_loss did not improve from 0.00310
# Epoch 34/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00034: val_loss did not improve from 0.00310
# Epoch 35/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00035: val_loss did not improve from 0.00310
# Epoch 36/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00036: val_loss did not improve from 0.00310
# Epoch 37/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0022 - val_loss: 0.0034
#
# Epoch 00037: val_loss did not improve from 0.00310
# Epoch 38/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0022 - val_loss: 0.0034
#
# Epoch 00038: val_loss did not improve from 0.00310
# Epoch 39/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0021 - val_loss: 0.0035
#
# Epoch 00039: val_loss did not improve from 0.00310
# Epoch 40/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0021 - val_loss: 0.0037
#
# Epoch 00040: val_loss did not improve from 0.00310
# Epoch 41/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0020 - val_loss: 0.0031
#
# Epoch 00041: val_loss improved from 0.00310 to 0.00309, saving model to model-unet.h5
# Epoch 42/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0020 - val_loss: 0.0031
#
# Epoch 00042: val_loss did not improve from 0.00309
# Epoch 43/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0020 - val_loss: 0.0033
#
# Epoch 00043: val_loss did not improve from 0.00309
# Epoch 44/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0019 - val_loss: 0.0032
#
# Epoch 00044: val_loss did not improve from 0.00309
# Epoch 45/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0019 - val_loss: 0.0035
#
# Epoch 00045: val_loss did not improve from 0.00309
# Epoch 46/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0019 - val_loss: 0.0032
#
# Epoch 00046: val_loss did not improve from 0.00309
# Epoch 47/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0018 - val_loss: 0.0031
#
# Epoch 00047: val_loss did not improve from 0.00309
# Epoch 48/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0018 - val_loss: 0.0033
#
# Epoch 00048: val_loss did not improve from 0.00309
# Epoch 49/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0018 - val_loss: 0.0033
#
# Epoch 00049: val_loss did not improve from 0.00309
# Epoch 50/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0033
#
# Epoch 00050: val_loss did not improve from 0.00309
# Epoch 51/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0033
#
# Epoch 00051: val_loss did not improve from 0.00309
# Epoch 52/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0036
#
# Epoch 00052: val_loss did not improve from 0.00309
# Epoch 53/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0035
#
# Epoch 00053: val_loss did not improve from 0.00309
# Epoch 54/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0034
#
# Epoch 00054: val_loss did not improve from 0.00309
# Epoch 55/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0016 - val_loss: 0.0040
#
# Epoch 00055: val_loss did not improve from 0.00309
# Epoch 56/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0016 - val_loss: 0.0033
#
# Epoch 00056: val_loss did not improve from 0.00309
# Epoch 57/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0017 - val_loss: 0.0038
#
# Epoch 00057: val_loss did not improve from 0.00309
# Epoch 58/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0035
#
# Epoch 00058: val_loss did not improve from 0.00309
# Epoch 59/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0036
#
# Epoch 00059: val_loss did not improve from 0.00309
# Epoch 60/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0032
#
# Epoch 00060: val_loss did not improve from 0.00309
# Epoch 61/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0015 - val_loss: 0.0035
#
# Epoch 00061: val_loss did not improve from 0.00309
# Epoch 62/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0032
#
# Epoch 00062: val_loss did not improve from 0.00309
# Epoch 63/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0040
#
# Epoch 00063: val_loss did not improve from 0.00309
# Epoch 64/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0035
#
# Epoch 00064: val_loss did not improve from 0.00309
# Epoch 65/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0032
#
# Epoch 00065: val_loss did not improve from 0.00309
# Epoch 66/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0014 - val_loss: 0.0034
#
# Epoch 00066: val_loss did not improve from 0.00309
# Epoch 67/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0034
#
# Epoch 00067: val_loss did not improve from 0.00309
# Epoch 68/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0035
#
# Epoch 00068: val_loss did not improve from 0.00309
# Epoch 69/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0036
#
# Epoch 00069: val_loss did not improve from 0.00309
# Epoch 70/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0034
#
# Epoch 00070: val_loss did not improve from 0.00309
# Epoch 71/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0035
#
# Epoch 00071: val_loss did not improve from 0.00309
# Epoch 72/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0013 - val_loss: 0.0031
#
# Epoch 00072: val_loss did not improve from 0.00309
# Epoch 73/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0034
#
# Epoch 00073: val_loss did not improve from 0.00309
# Epoch 74/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0037
#
# Epoch 00074: val_loss did not improve from 0.00309
# Epoch 75/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0035
#
# Epoch 00075: val_loss did not improve from 0.00309
# Epoch 76/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0034
#
# Epoch 00076: val_loss did not improve from 0.00309
# Epoch 77/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0032
#
# Epoch 00077: val_loss did not improve from 0.00309
# Epoch 78/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0033
#
# Epoch 00078: val_loss did not improve from 0.00309
# Epoch 79/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0031
#
# Epoch 00079: val_loss did not improve from 0.00309
# Epoch 80/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0012 - val_loss: 0.0039
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00080: val_loss did not improve from 0.00309
# Epoch 81/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0034
#
# Epoch 00081: val_loss did not improve from 0.00309
# Epoch 82/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0034
#
# Epoch 00082: val_loss did not improve from 0.00309
# Epoch 83/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00083: val_loss did not improve from 0.00309
# Epoch 84/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00084: val_loss did not improve from 0.00309
# Epoch 85/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00085: val_loss did not improve from 0.00309
# Epoch 86/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00086: val_loss did not improve from 0.00309
# Epoch 87/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0034
#
# Epoch 00087: val_loss did not improve from 0.00309
# Epoch 88/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0034
#
# Epoch 00088: val_loss did not improve from 0.00309
# Epoch 89/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0034
#
# Epoch 00089: val_loss did not improve from 0.00309
# Epoch 90/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00090: val_loss did not improve from 0.00309
# Epoch 91/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00091: val_loss did not improve from 0.00309
# Epoch 92/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00092: val_loss did not improve from 0.00309
# Epoch 93/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00093: val_loss did not improve from 0.00309
# Epoch 94/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00094: val_loss did not improve from 0.00309
# Epoch 95/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00095: val_loss did not improve from 0.00309
# Epoch 96/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00096: val_loss did not improve from 0.00309
# Epoch 97/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00097: val_loss did not improve from 0.00309
# Epoch 98/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0034
#
# Epoch 00098: val_loss did not improve from 0.00309
# Epoch 99/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00099: val_loss did not improve from 0.00309
# Epoch 100/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00100: val_loss did not improve from 0.00309
# Epoch 101/800
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0035
#
# Epoch 00101: val_loss did not improve from 0.00309
# Epoch 00101: early stopping

# %% [markdown]
# Test model

# %%
# load the best model
unet.load_weights('model-unet.h5')

y_pred = unet.predict(x_test)

plt.figure(figsize=(15,12))
plt.subplot(2,5,1)
plt.imshow(x_test[0,:,:,0], 'gray')
plt.title('input test1(data with noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,2)
plt.imshow(y_pred[0,:,:,0], 'gray')
plt.title('prediction test1')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,3)
plt.imshow(y_test[0,:,:,0], 'gray')
plt.title('ground truth1(data wo noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,4)
plt.imshow(abs(y_test[0,:,:,0]-y_pred[0,:,:,0]), 'jet')
plt.title('prediction difference')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,5)
plt.imshow(abs(x_test[0,:,:,0]-y_test[0,:,:,0]), 'jet')
plt.title('input difference')
plt.xlabel('channel')
plt.ylabel('depth')


plt.subplot(2,5,6)
plt.imshow(x_test[1,:,:,0], 'gray')
plt.title('input test2(data with noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,7)
plt.imshow(y_pred[1,:,:,0], 'gray')
plt.title('prediction test2')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,8)
plt.imshow(y_test[1,:,:,0], 'gray')
plt.title('ground truth1(data wo noise)')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,9)
plt.imshow(abs(y_test[1,:,:,0]-y_pred[1,:,:,0]), 'jet')
plt.title('prediction difference')
plt.xlabel('channel')
plt.ylabel('depth')
plt.subplot(2,5,10)
plt.imshow(abs(x_test[1,:,:,0]-y_test[1,:,:,0]), 'jet')
plt.title('input difference')
plt.xlabel('channel')
plt.ylabel('depth')
plt.show()
